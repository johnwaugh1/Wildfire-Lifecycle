# %%
import ee
import geemap
import os
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

ee.Authenticate()
ee.Initialize(project='wildfire-lifecycle')

# %% [markdown]
# Define Fire Case Studies (Same as previous notebook)

# %%
fires = {
    "Dixie": {
        "coords": [-121.3, 40.0],
        "buffer_km": 30,
        "start_date": "2021-07-01",
        "end_date": "2021-10-01",
    },
    "Camp": {
        "coords": [-121.4, 39.8],
        "buffer_km": 30,
        "start_date": "2018-11-01",
        "end_date": "2018-12-15",
    },
    "Troublesome": {
        "coords": [-106.2, 40.0],
        "buffer_km": 30,
        "start_date": "2020-10-01",
        "end_date": "2020-11-15",
    },
    "Caldor": {
        "coords": [-120.8, 38.6],
        "buffer_km": 30,
        "start_date": "2021-08-01",
        "end_date": "2021-10-01",
    },
    "Bootleg": {
        "coords": [-121.3, 42.5],
        "buffer_km": 40,
        "start_date": "2021-07-01",
        "end_date": "2021-09-01",
    },
    "Carr": {
        "coords": [-122.3, 40.6],
        "buffer_km": 30,
        "start_date": "2018-07-23",
        "end_date": "2018-09-04",
    },
    "Thomas": {
        "coords": [-119.4, 34.5],
        "buffer_km": 30,
        "start_date": "2017-12-04",
        "end_date": "2018-01-12",
    },
    "Creek": {
        "coords": [-119.9, 37.4],
        "buffer_km": 30,
        "start_date": "2020-09-04",
        "end_date": "2020-12-24",
    },
    "Woolsey": {
        "coords": [-118.7, 34.1],
        "buffer_km": 25,
        "start_date": "2018-11-08",
        "end_date": "2018-11-21",
    },
    "Glass": {
        "coords": [-122.45, 38.55],
        "buffer_km": 25,
        "start_date": "2020-09-27",
        "end_date": "2020-10-20",
    },
}

output_dir = "../data/processed"
os.makedirs(output_dir, exist_ok=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Helper Functions

# %%
def get_aoi(fire):
    point = ee.Geometry.Point(fire["coords"])
    return point.buffer(fire["buffer_km"] * 1000).bounds()

def mask_s2_clouds(image):
    """Cloud mask for Sentinel-2."""
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
        qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask).divide(10000)

def compute_indices(image):
    """Generate NDVI, EVI, NBR."""
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    evi = image.expression(
        '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
            'NIR': image.select('B8'),
            'RED': image.select('B4'),
            'BLUE': image.select('B2')
        }).rename('EVI')
    nbr = image.normalizedDifference(['B8', 'B12']).rename('NBR')
    return image.addBands([ndvi, evi, nbr])

def compute_spi(aoi, start_date, end_date):
    """ Compute Standardized Precipitation Index (SPI) using CHIRPS data. """
    chirps = (ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY")
              .filterDate(start_date, end_date)
              .filterBounds(aoi))
    
    total_precip = chirps.select("precipitation").sum().rename("precip_total")
    longterm = ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY").filterDate("1981-01-01", "2020-12-31").select("precipitation")
    
    mean = longterm.mean().rename("mean")
    std = longterm.reduce(ee.Reducer.stdDev()).rename("std")
    
    spi = total_precip.subtract(mean).divide(std).rename("SPI")
    return spi


def export_image(image, name, aoi, scale=500):
    out_path = os.path.join(output_dir, f"{name}.tif")
    geemap.ee_export_image(
        image,
        filename=out_path,
        scale=scale,
        region=aoi,
        file_per_band=False
    )
    print(f"Exported {name} to {out_path}")

def visualize_raster(image, vis_params, aoi, name="layer"):
    """Quick visualization using geemap."""
    Map = geemap.Map()
    Map.centerObject(aoi, 9)
    Map.addLayer(image, vis_params, name)
    return Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Visualization Check

# %%
aoi = get_aoi(fires["Dixie"])
s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
      .filterDate(fires["Dixie"]["start_date"], fires["Dixie"]["end_date"])
      .filterBounds(aoi)
      .map(mask_s2_clouds)
      .median())
s2_indices = compute_indices(s2)

Map = visualize_raster(
    s2_indices.select("NDVI"),
    {"min": 0, "max": 1, "palette": ["white", "green"]},
    aoi,
    "NDVI"
)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.99987156352278, -121.29928808513878], controls=(WidgetControl(options=['position', 'transparent…

# %% [markdown]
# Loop through fires

# %%
for fire_name, fire_info in fires.items():
    print(f"Processing {fire_name} Fire")
    # Standardize date keys
    start_date = fire_info.get("start_date", fire_info.get("start"))
    end_date = fire_info.get("end_date", fire_info.get("end"))
    aoi = get_aoi(fire_info)

    # Sentinel-2 Composite (cloud-masked)
    s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
          .filterDate(start_date, end_date)
          .filterBounds(aoi)
          .map(mask_s2_clouds)
          .median())
    
    s2_with_indices = compute_indices(s2)

    # Drought Index (VCI from MODIS NDVI)
    vci = (ee.ImageCollection("MODIS/061/MOD13A2")
           .filterDate(start_date, end_date)
           .filterBounds(aoi)
           .select("NDVI")
           .map(lambda img: img.unitScale(0, 10000))  # scale to 0-1
           .mean()
           .rename("VCI"))

    # SPI Calculation (precipitation anomaly)
    spi = compute_spi(aoi, start_date, end_date)

    # Burn severity label (dNBR)
    prefire = s2_with_indices.select('NBR')
    postfire = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
                .filterDate(
                    (datetime.strptime(end_date, "%Y-%m-%d") + timedelta(days=30)).strftime("%Y-%m-%d"),
                    (datetime.strptime(end_date, "%Y-%m-%d") + timedelta(days=120)).strftime("%Y-%m-%d"))
                .filterBounds(aoi)
                .map(mask_s2_clouds)
                .median()
                .normalizedDifference(['B8', 'B12'])
                .rename('NBR'))
    dNBR = prefire.subtract(postfire).rename('dNBR')

    # Export layers
    export_image(s2_with_indices.select(['NDVI', 'EVI', 'NBR']), f"{fire_name}_veg_indices", aoi, scale=50)
    export_image(vci, f"{fire_name}_VCI", aoi, scale=500)
    export_image(spi, f"{fire_name}_SPI", aoi, scale=500)
    export_image(dNBR, f"{fire_name}_dNBR", aoi, scale=50)

print("Preprocessing complete")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing Dixie Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/4f87656eaaf74de1f4b2d3b142d8b95c-14279ebb2bc6188a4cb7878e26bba1a2:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_veg_indices.tif
# Exported Dixie_veg_indices to ../data/processed\Dixie_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/ae3749ab4f348604a2ee3988f784aa98-315562cb4294ec0ba17135d1a4a01e56:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_VCI.tif
# Exported Dixie_VCI to ../data/processed\Dixie_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/129090b06bfb2979b57ae7c98b53bbce-37c6c892f8452938a86c46b715d444a0:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_SPI.tif
# Exported Dixie_SPI to ../data/processed\Dixie_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/7a0166630481c7bc8790a4d123f7eacf-530d156ac12679c839535fa223707ec0:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_dNBR.tif
# Exported Dixie_dNBR to ../data/processed\Dixie_dNBR.tif
# Processing Camp Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/7a8288ff4cc65ab5e1e14120615d1900-60c852560eb25a0c4876659331042d73:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_veg_indices.tif
# Exported Camp_veg_indices to ../data/processed\Camp_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/4f304d23c0d2a2814acbe2eabb529ffd-e01a090d28996a8230f2cd276030714c:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_VCI.tif
# Exported Camp_VCI to ../data/processed\Camp_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/675ce9a7a8d596e9d84c4b2affc330db-af1321b1d7c1946a54277a58cc2f560a:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_SPI.tif
# Exported Camp_SPI to ../data/processed\Camp_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/348396da2e6f4e737d1ef6295f30373b-1df58ff86a3cd06cfe756432d19aec9a:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_dNBR.tif
# Exported Camp_dNBR to ../data/processed\Camp_dNBR.tif
# Processing Troublesome Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/ab69a04580e3c4647ecbe16ced3faea5-427dbda144860ae686c671182e46cf2e:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Troublesome_veg_indices.tif
# Exported Troublesome_veg_indices to ../data/processed\Troublesome_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/504949ec845106c9f1a55f748a8014fd-6d107f9f43c21eb9bd374328fc1ed8fd:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Troublesome_VCI.tif
# Exported Troublesome_VCI to ../data/processed\Troublesome_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/a5a44fd57a337f58836c52256af9d991-b8c806d10bc59e025a1e2154acc314d2:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Troublesome_SPI.tif
# Exported Troublesome_SPI to ../data/processed\Troublesome_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/789949d155510455fd7614334abee160-bc690601bddd401f14f578e3414e0283:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Troublesome_dNBR.tif
# Exported Troublesome_dNBR to ../data/processed\Troublesome_dNBR.tif
# Processing Caldor Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/a363e1cd6d79ed6dee9a508f5a0c4d3b-ab46aa22749b62ebdd452f26c6a3e56a:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Caldor_veg_indices.tif
# Exported Caldor_veg_indices to ../data/processed\Caldor_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/335b3062f17efb7f2dc465b5994e5bf2-0372c99dc0adf353988e1ae8a25ecdfa:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Caldor_VCI.tif
# Exported Caldor_VCI to ../data/processed\Caldor_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/2ce906c55d28f77a655599dc4493e29b-704f7d30b48e94e00a56e8d31d8073e3:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Caldor_SPI.tif
# Exported Caldor_SPI to ../data/processed\Caldor_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/e0d5b86f877256fe95554aaefcfd1a8c-f128f82812f6193381a9de6e5ffd5945:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Caldor_dNBR.tif
# Exported Caldor_dNBR to ../data/processed\Caldor_dNBR.tif
# Processing Bootleg Fire
# Generating URL ...
# An error occurred while downloading.
# Total request size (65817577 bytes) must be less than or equal to 50331648 bytes.
# Exported Bootleg_veg_indices to ../data/processed\Bootleg_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/cc722168ac409c2831d93aba7201236d-fc59a7519b3a9c4502c431eac4aa3912:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Bootleg_VCI.tif
# Exported Bootleg_VCI to ../data/processed\Bootleg_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/29125a0b3f300e508be686bc3bbc187e-f10d8106653370b4394e3bd753e61278:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Bootleg_SPI.tif
# Exported Bootleg_SPI to ../data/processed\Bootleg_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/9ef252c1c52243b91262a4e141a5235d-53482bfcd2872ce1e518e0b56aa3724a:getPixels
# Please wait ...
# An error occurred while downloading.
# Exported Bootleg_dNBR to ../data/processed\Bootleg_dNBR.tif
# Processing Carr Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/fc7ee88349d2534a4176370c8dc10a0a-b97479632e681aa2209a39f1e926935a:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Carr_veg_indices.tif
# Exported Carr_veg_indices to ../data/processed\Carr_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/87fa152862b97883d70fc50f8f07ada3-6be1ab8261fb23f16a6d1b8d3015929b:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Carr_VCI.tif
# Exported Carr_VCI to ../data/processed\Carr_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/1dbd4d6c66a28deffa521cddb41201cc-e387c9995b179feaa26d8349f3bb8df7:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Carr_SPI.tif
# Exported Carr_SPI to ../data/processed\Carr_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails