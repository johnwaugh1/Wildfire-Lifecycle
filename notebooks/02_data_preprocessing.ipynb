# %%
import ee
import geemap
import os
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

ee.Authenticate()
ee.Initialize()
# Out:
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6

# %% [markdown]
# Define Fire Case Studies (Same as previous notebook)

# %%
fires = {
    "Dixie": {
        "coords": [-121.3, 40.0],
        "buffer_km": 30,
        "start_date": "2021-07-01",
        "end_date": "2021-10-01",
    },
    "Camp": {
        "coords": [-121.4, 39.8],
        "buffer_km": 30,
        "start_date": "2018-11-01",
        "end_date": "2018-12-15",
    },
    "Creek": {
        "coords": [-119.4, 37.1],
        "buffer_km": 30,
        "start_date": "2020-09-01",
        "end_date": "2020-11-15",
    },
    "CZU": {
        "coords": [-122.3, 37.2],
        "buffer_km": 20,
        "start_date": "2020-08-01",
        "end_date": "2020-10-01",
    },
    "Bootleg": {
        "coords": [-121.3, 42.5],
        "buffer_km": 40,
        "start_date": "2021-07-01",
        "end_date": "2021-09-01",
    },
}

output_dir = "../data/processed"
os.makedirs(output_dir, exist_ok=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Helper Functions

# %%
def get_aoi(fire):
    point = ee.Geometry.Point(fire["coords"])
    return point.buffer(fire["buffer_km"] * 1000).bounds()

def mask_s2_clouds(image):
    """Cloud mask for Sentinel-2."""
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
        qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask).divide(10000)

def compute_indices(image):
    """Generate NDVI, EVI, NBR."""
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    evi = image.expression(
        '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
            'NIR': image.select('B8'),
            'RED': image.select('B4'),
            'BLUE': image.select('B2')
        }).rename('EVI')
    nbr = image.normalizedDifference(['B8', 'B12']).rename('NBR')
    return image.addBands([ndvi, evi, nbr])

def compute_spi(aoi, start_date, end_date):
    """ Compute Standardized Precipitation Index (SPI) using CHIRPS data. """
    chirps = (ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY")
              .filterDate(start_date, end_date)
              .filterBounds(aoi))
    
    total_precip = chirps.select("precipitation").sum().rename("precip_total")
    longterm = ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY").filterDate("1981-01-01", "2020-12-31").select("precipitation")
    
    mean = longterm.mean().rename("mean")
    std = longterm.reduce(ee.Reducer.stdDev()).rename("std")
    
    spi = total_precip.subtract(mean).divide(std).rename("SPI")
    return spi


def export_image(image, name, aoi, scale=500):
    out_path = os.path.join(output_dir, f"{name}.tif")
    geemap.ee_export_image(
        image,
        filename=out_path,
        scale=scale,
        region=aoi,
        file_per_band=False
    )
    print(f"Exported {name} to {out_path}")

def visualize_raster(image, vis_params, aoi, name="layer"):
    """Quick visualization using geemap."""
    Map = geemap.Map()
    Map.centerObject(aoi, 9)
    Map.addLayer(image, vis_params, name)
    return Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Visualization Check

# %%
aoi = get_aoi(fires["Dixie"])
s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
      .filterDate(fires["Dixie"]["start_date"], fires["Dixie"]["end_date"])
      .filterBounds(aoi)
      .map(mask_s2_clouds)
      .median())
s2_indices = compute_indices(s2)

Map = visualize_raster(
    s2_indices.select("NDVI"),
    {"min": 0, "max": 1, "palette": ["white", "green"]},
    aoi,
    "NDVI"
)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.99987156352278, -121.29928808513878], controls=(WidgetControl(options=['position', 'transparent…

# %% [markdown]
# Loop through fires

# %%
for fire_name, fire_info in fires.items():
    print(f"Processing {fire_name} Fire")
    aoi = get_aoi(fire_info)

    # Sentinel-2 Composite (cloud-masked)
    s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
          .filterDate(fire_info["start_date"], fire_info["end_date"])
          .filterBounds(aoi)
          .map(mask_s2_clouds)
          .median())
    
    s2_with_indices = compute_indices(s2)

    # Drought Index (VCI from MODIS NDVI)
    vci = (ee.ImageCollection("MODIS/061/MOD13A2")
           .filterDate(fire_info["start_date"], fire_info["end_date"])
           .filterBounds(aoi)
           .select("NDVI")
           .map(lambda img: img.unitScale(0, 10000))  # scale to 0-1
           .mean()
           .rename("VCI"))

    # SPI Calculation (precipitation anomaly)
    spi = compute_spi(aoi, fire_info["start_date"], fire_info["end_date"])

    # Burn severity label (dNBR)
    prefire = s2_with_indices.select('NBR')
    postfire = (ee.ImageCollection("COPERNICUS/S2_SR")
                .filterDate(
                    (datetime.strptime(fire_info["end_date"], "%Y-%m-%d") + timedelta(days=30)).strftime("%Y-%m-%d"),
                    (datetime.strptime(fire_info["end_date"], "%Y-%m-%d") + timedelta(days=120)).strftime("%Y-%m-%d"))
                .filterBounds(aoi)
                .map(mask_s2_clouds)
                .median()
                .normalizedDifference(['B8', 'B12'])
                .rename('NBR'))
    dNBR = prefire.subtract(postfire).rename('dNBR')

    # Export layers
    export_image(s2_with_indices.select(['NDVI', 'EVI', 'NBR']), f"{fire_name}_veg_indices", aoi, scale=50)
    export_image(vci, f"{fire_name}_VCI", aoi, scale=500)
    export_image(spi, f"{fire_name}_SPI", aoi, scale=500)
    export_image(dNBR, f"{fire_name}_dNBR", aoi, scale=50)

print("Preprocessing complete")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing Dixie Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/a8e0a52b6358b9c0547a538af0831944-341238ddc2a6deb4a9f9451f419e3037:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_veg_indices.tif
# Exported Dixie_veg_indices to ../data/processed\Dixie_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/de0db9137e08e8f531bed20fbf806f39-23c5b2aea843b281ee172cb585f4a6e8:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_VCI.tif
# Exported Dixie_VCI to ../data/processed\Dixie_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/1a434123121951fa3d63917d2286f701-606eaa33cd810206420e8b5c3343ec36:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_SPI.tif
# Exported Dixie_SPI to ../data/processed\Dixie_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/8dba8273fc84f50f1c807598684f0f58-723a30675aa7d35566519ac12a1a6a06:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Dixie_dNBR.tif
# Exported Dixie_dNBR to ../data/processed\Dixie_dNBR.tif
# Processing Camp Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/796ddb945690b3231087fa3719f39c1c-350ea55f764bae67bd0cba0eb291a62f:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_veg_indices.tif
# Exported Camp_veg_indices to ../data/processed\Camp_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/295553fedf74cd7441ce2026727223dc-e8da4a8e554246957ab57755ec6ba680:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_VCI.tif
# Exported Camp_VCI to ../data/processed\Camp_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/f228c2ec76a4ff92fbd6087e7895bd34-d52557cc60679105fcce90364fd57b29:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_SPI.tif
# Exported Camp_SPI to ../data/processed\Camp_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/403023d4f69a88d9e888a3c2687cd961-72876bf2ee12b35ae51ce2370d594530:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Camp_dNBR.tif
# Exported Camp_dNBR to ../data/processed\Camp_dNBR.tif
# Processing Creek Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/28d571e56c5002c98e7ac387df8b4afe-c9e94130c9f66b1e8d0e2430b80ddd31:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Creek_veg_indices.tif
# Exported Creek_veg_indices to ../data/processed\Creek_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/8720bd816763b4687c63922bb204a09f-3dd1b76ec37c1f451c88fe913aba26d5:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Creek_VCI.tif
# Exported Creek_VCI to ../data/processed\Creek_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/8fe258e72d7c3a86e000fb9933123541-45c75a9d3f9838ed0f5982d1f93765a2:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Creek_SPI.tif
# Exported Creek_SPI to ../data/processed\Creek_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/b4e5d2f629eb04a09f47e42116a1adc8-2dcb4565bd9f7b672c8b314fbd0590bd:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Creek_dNBR.tif
# Exported Creek_dNBR to ../data/processed\Creek_dNBR.tif
# Processing CZU Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/e89a451ccc0fc1f91ca90acd83e8afd0-100e54fdaeddf64ab0a79803ab26e64b:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\CZU_veg_indices.tif
# Exported CZU_veg_indices to ../data/processed\CZU_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/e94f2ae22f5702c0d0ce234d8df34904-15c3368b93d0d4f937f15dcac9a1f2bd:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\CZU_VCI.tif
# Exported CZU_VCI to ../data/processed\CZU_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/6560124444a22f73a10c47a398549bb7-ef4e77ef95532e00ef40a7f2b5aed769:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\CZU_SPI.tif
# Exported CZU_SPI to ../data/processed\CZU_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/a13b48a32fb17335943af3bebdb6cdd2-8e28d051e9d5f11e8149cf03fbf5515a:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\CZU_dNBR.tif
# Exported CZU_dNBR to ../data/processed\CZU_dNBR.tif
# Processing Bootleg Fire
# Generating URL ...
# An error occurred while downloading.
# Total request size (65817577 bytes) must be less than or equal to 50331648 bytes.
# Exported Bootleg_veg_indices to ../data/processed\Bootleg_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/1cdab1db00d6c83e1aefd02ea1897e12-1dca543d97f523873b53379a145dca56:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Bootleg_VCI.tif
# Exported Bootleg_VCI to ../data/processed\Bootleg_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/6bc1e4ee2c560707d11bd0c0d7289a14-7f796182ac3e1c9c690b7408b166d658:getPixels
# Please wait ...
# Data downloaded to c:\Users\John Waugh\Desktop\CS Projects\Wildfire-Lifecycle\data\processed\Bootleg_SPI.tif
# Exported Bootleg_SPI to ../data/processed\Bootleg_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/230892076054/thumbnails/06da71cbfe77500368e42f444c3302b7-5edde9e3cad4fe247a4c820b86b94e45:getPixels
# Please wait ...
# An error occurred while downloading.
# Exported Bootleg_dNBR to ../data/processed\Bootleg_dNBR.tif
# Preprocessing complete
