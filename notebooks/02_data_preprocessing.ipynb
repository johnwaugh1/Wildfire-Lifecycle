# %%
import ee
import geemap
import os
import numpy as np
import xarray as xr
from datetime import datetime, timedelta

ee.Authenticate()
ee.Initialize(project='wildfire-lifecycle')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Define Fire Case Studies (Same as previous notebook)

# %%
fires = {
    "Dixie": {
        "coords": [-121.3, 40.0],
        "buffer_km": 30,
        "start_date": "2021-07-01",
        "end_date": "2021-10-01",
    },
    "Camp": {
        "coords": [-121.4, 39.8],
        "buffer_km": 30,
        "start_date": "2018-11-01",
        "end_date": "2018-12-15",
    },
    "Troublesome": {
        "coords": [-106.2, 40.0],
        "buffer_km": 30,
        "start_date": "2020-10-01",
        "end_date": "2020-11-15",
    },
    "Caldor": {
        "coords": [-120.8, 38.6],
        "buffer_km": 30,
        "start_date": "2021-08-01",
        "end_date": "2021-10-01",
    },
    "Bootleg": {
        "coords": [-121.3, 42.5],
        "buffer_km": 40,
        "start_date": "2021-07-01",
        "end_date": "2021-09-01",
    },
    "Carr": {
        "coords": [-122.3, 40.6],
        "buffer_km": 30,
        "start_date": "2018-07-23",
        "end_date": "2018-09-04",
    },
    "Thomas": {
        "coords": [-119.4, 34.5],
        "buffer_km": 30,
        "start_date": "2017-12-04",
        "end_date": "2018-01-12",
    },
    "Creek": {
        "coords": [-119.9, 37.4],
        "buffer_km": 30,
        "start_date": "2020-09-04",
        "end_date": "2020-12-24",
    },
    "Woolsey": {
        "coords": [-118.7, 34.1],
        "buffer_km": 25,
        "start_date": "2018-11-08",
        "end_date": "2018-11-21",
    },
    "Glass": {
        "coords": [-122.45, 38.55],
        "buffer_km": 25,
        "start_date": "2020-09-27",
        "end_date": "2020-10-20",
    },
}

output_dir = "../data/processed"
os.makedirs(output_dir, exist_ok=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Helper Functions

# %%
def get_aoi(fire):
    point = ee.Geometry.Point(fire["coords"])
    return point.buffer(fire["buffer_km"] * 1000).bounds()

def mask_s2_clouds(image):
    """Cloud mask for Sentinel-2."""
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
        qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask).divide(10000)

def compute_indices(image):
    """Generate NDVI, EVI, NBR."""
    ndvi = image.normalizedDifference(['B8', 'B4']).rename('NDVI')
    evi = image.expression(
        '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))', {
            'NIR': image.select('B8'),
            'RED': image.select('B4'),
            'BLUE': image.select('B2')
        }).rename('EVI')
    nbr = image.normalizedDifference(['B8', 'B12']).rename('NBR')
    return image.addBands([ndvi, evi, nbr])

def compute_spi(aoi, start_date, end_date):
    """ Compute Standardized Precipitation Index (SPI) using CHIRPS data. """
    chirps = (ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY")
              .filterDate(start_date, end_date)
              .filterBounds(aoi))
    
    total_precip = chirps.select("precipitation").sum().rename("precip_total")
    longterm = ee.ImageCollection("UCSB-CHG/CHIRPS/DAILY").filterDate("1981-01-01", "2020-12-31").select("precipitation")
    
    mean = longterm.mean().rename("mean")
    std = longterm.reduce(ee.Reducer.stdDev()).rename("std")
    
    spi = total_precip.subtract(mean).divide(std).rename("SPI")
    return spi


def export_image(image, name, aoi, scale=500):
    out_path = os.path.join(output_dir, f"{name}.tif")
    geemap.ee_export_image(
        image,
        filename=out_path,
        scale=scale,
        region=aoi,
        file_per_band=False
    )
    print(f"Exported {name} to {out_path}")

def visualize_raster(image, vis_params, aoi, name="layer"):
    """Quick visualization using geemap."""
    Map = geemap.Map()
    Map.centerObject(aoi, 9)
    Map.addLayer(image, vis_params, name)
    return Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Visualization Check

# %%
aoi = get_aoi(fires["Dixie"])
s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
      .filterDate(fires["Dixie"]["start_date"], fires["Dixie"]["end_date"])
      .filterBounds(aoi)
      .map(mask_s2_clouds)
      .median())
s2_indices = compute_indices(s2)

Map = visualize_raster(
    s2_indices.select("NDVI"),
    {"min": 0, "max": 1, "palette": ["white", "green"]},
    aoi,
    "NDVI"
)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.99987156352278, -121.29928808513878], controls=(WidgetControl(options=['position', 'transparent…

# %% [markdown]
# Loop through fires

# %%
for fire_name, fire_info in fires.items():
    print(f"Processing {fire_name} Fire")
    # Standardize date keys
    start_date = fire_info.get("start_date", fire_info.get("start"))
    end_date = fire_info.get("end_date", fire_info.get("end"))
    aoi = get_aoi(fire_info)

    # Sentinel-2 Composite (cloud-masked)
    s2 = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
          .filterDate(start_date, end_date)
          .filterBounds(aoi)
          .map(mask_s2_clouds)
          .median())
    
    s2_with_indices = compute_indices(s2)

    # Drought Index (VCI from MODIS NDVI)
    vci = (ee.ImageCollection("MODIS/061/MOD13A2")
           .filterDate(start_date, end_date)
           .filterBounds(aoi)
           .select("NDVI")
           .map(lambda img: img.unitScale(0, 10000))  # scale to 0-1
           .mean()
           .rename("VCI"))

    # SPI Calculation (precipitation anomaly)
    spi = compute_spi(aoi, start_date, end_date)

    # Burn severity label (dNBR)
    prefire = s2_with_indices.select('NBR')
    postfire = (ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
                .filterDate(
                    (datetime.strptime(end_date, "%Y-%m-%d") + timedelta(days=30)).strftime("%Y-%m-%d"),
                    (datetime.strptime(end_date, "%Y-%m-%d") + timedelta(days=120)).strftime("%Y-%m-%d"))
                .filterBounds(aoi)
                .map(mask_s2_clouds)
                .median()
                .normalizedDifference(['B8', 'B12'])
                .rename('NBR'))
    dNBR = prefire.subtract(postfire).rename('dNBR')

    # Export layers
    export_image(s2_with_indices.select(['NDVI', 'EVI', 'NBR']), f"{fire_name}_veg_indices", aoi, scale=50)
    export_image(vci, f"{fire_name}_VCI", aoi, scale=500)
    export_image(spi, f"{fire_name}_SPI", aoi, scale=500)
    export_image(dNBR, f"{fire_name}_dNBR", aoi, scale=50)

print("Preprocessing complete")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing Dixie Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/a569c598df83c162a78896d8e11a13ea-302bbcb8f7c9f471a49b594db39f7c0d:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Dixie_veg_indices.tif
# Exported Dixie_veg_indices to ../data/processed\Dixie_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/ae3749ab4f348604a2ee3988f784aa98-82dfa5f2b0f268a9039e63ad043dc891:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Dixie_VCI.tif
# Exported Dixie_VCI to ../data/processed\Dixie_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/129090b06bfb2979b57ae7c98b53bbce-e9841779a01ad1bbdd218f5581d9b738:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Dixie_SPI.tif
# Exported Dixie_SPI to ../data/processed\Dixie_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/1b319dd8f57c18ad08bac91682b12b66-5bf6b7e2017cc138545958899043ebb5:getPixels
# Please wait ...
# An error occurred while downloading.
# Exported Dixie_dNBR to ../data/processed\Dixie_dNBR.tif
# Processing Camp Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/f11872bccc50a084c13275eedf41ea4f-de3223779894c67e1dd27701e1bf89b3:getPixels
# Please wait ...
# An error occurred while downloading.
# Exported Camp_veg_indices to ../data/processed\Camp_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/4f304d23c0d2a2814acbe2eabb529ffd-b201eba4cf5131d762402124c5590e9a:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Camp_VCI.tif
# Exported Camp_VCI to ../data/processed\Camp_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/9f1da9ac360805da96e6c650f370848d-6a5877bdd1f4fe1a393738a15f9991a3:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Camp_SPI.tif
# Exported Camp_SPI to ../data/processed\Camp_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/33510bb73d7247b1e426b07e3e29ffeb-b426dfa1728a7d3158fe122b4ef248dc:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Camp_dNBR.tif
# Exported Camp_dNBR to ../data/processed\Camp_dNBR.tif
# Processing Troublesome Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/d2805260c0b23c1e959ae4a2cb962225-ae62fccc84f829e4be513ef6cebf43ff:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Troublesome_veg_indices.tif
# Exported Troublesome_veg_indices to ../data/processed\Troublesome_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/504949ec845106c9f1a55f748a8014fd-3c09bde159db461a04f46fc09a388d3a:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Troublesome_VCI.tif
# Exported Troublesome_VCI to ../data/processed\Troublesome_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/a5a44fd57a337f58836c52256af9d991-76715e4f976ec46972621ceae7e595f5:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Troublesome_SPI.tif
# Exported Troublesome_SPI to ../data/processed\Troublesome_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/c7044e985c60ac25dc37dc9a1d9c8dd2-b5f3268cc46bca9a7aaaecfe6ef636a2:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Troublesome_dNBR.tif
# Exported Troublesome_dNBR to ../data/processed\Troublesome_dNBR.tif
# Processing Caldor Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/64ec8afc4acb5cac0657769bf7a311cd-46c74edcf8dca98b0a9e0df446e4c265:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Caldor_veg_indices.tif
# Exported Caldor_veg_indices to ../data/processed\Caldor_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/335b3062f17efb7f2dc465b5994e5bf2-5e34319a114f55f294d132460c81c4a3:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Caldor_VCI.tif
# Exported Caldor_VCI to ../data/processed\Caldor_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/2ce906c55d28f77a655599dc4493e29b-af41e5fe1ed7b3f9570418fb7eec3902:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Caldor_SPI.tif
# Exported Caldor_SPI to ../data/processed\Caldor_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/30efe462385e8be761b86d415bab1025-99fab5da2696f28e77e5b151612e1048:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Caldor_dNBR.tif
# Exported Caldor_dNBR to ../data/processed\Caldor_dNBR.tif
# Processing Bootleg Fire
# Generating URL ...
# An error occurred while downloading.
# Total request size (65817577 bytes) must be less than or equal to 50331648 bytes.
# Exported Bootleg_veg_indices to ../data/processed\Bootleg_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/cc722168ac409c2831d93aba7201236d-0bc752b9b3e1d384eda800443a6ea4e0:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Bootleg_VCI.tif
# Exported Bootleg_VCI to ../data/processed\Bootleg_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/29125a0b3f300e508be686bc3bbc187e-0837e2e77561fefa5eec9740f022282f:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Bootleg_SPI.tif
# Exported Bootleg_SPI to ../data/processed\Bootleg_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/826d118bb59ef16deb8dd7c77775a19d-d17b45db39e36bea1f204b25012fd002:getPixels
# Please wait ...
# An error occurred while downloading.
# Exported Bootleg_dNBR to ../data/processed\Bootleg_dNBR.tif
# Processing Carr Fire
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/d8f5c2223abcefbcfc936eddf0145a50-bf9d3e4d30f94e85a31be1f1a76fb487:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Carr_veg_indices.tif
# Exported Carr_veg_indices to ../data/processed\Carr_veg_indices.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/87fa152862b97883d70fc50f8f07ada3-14c1b7144914bde2d0ddb99f84c74b38:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Carr_VCI.tif
# Exported Carr_VCI to ../data/processed\Carr_VCI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails/1dbd4d6c66a28deffa521cddb41201cc-37f1c1b0997c6d2d6b5b17308084c7a5:getPixels
# Please wait ...
# Data downloaded to c:\Users\caren\Code\CAPSTONE\Wildfire-Lifecycle\data\processed\Carr_SPI.tif
# Exported Carr_SPI to ../data/processed\Carr_SPI.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/wildfire-lifecycle/thumbnails