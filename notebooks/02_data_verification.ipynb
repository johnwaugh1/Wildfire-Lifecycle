# %% [markdown]
# Imports

# %%
import os
import rasterio # For reading/writing raster data
from rasterio.errors import RasterioError # For handling raster-specific errors
import numpy as np # For checking arrays for NaN values

# Expected files per fire folder
expected_files = {
    "ndvi_pre": "pre_ndvi.tif",
    "ndvi_post": "post_ndvi.tif",
    "nbr_pre": "pre_nbr.tif",
    "nbr_post": "post_nbr.tif",
    "chirps_precip": "chirps_precip.tif",
    "era5_temp": "era5_temp.tif",
    "landcover": "landcover.tif",
    "srtm_dem": "srtm_dem.tif",
}

# %% [markdown]
# Validate all fire event folders exist and contain files required

# %%
def check_expected_files(fire_root, expected_files):
    print("\n# Checking folder structure and file existence #")

    # List all fire folders
    fire_folders = [
        os.path.join(fire_root, f) 
        for f in os.listdir(fire_root) 
        if os.path.isdir(os.path.join(fire_root, f))
    ]

    # Dictionary to store which files are present/missing per fire
    results = {}

    # Check each fire folder
    for folder in fire_folders:
        # Get fire folder name
        fire_name = os.path.basename(folder)
        print(f"\nChecking: {fire_name}")

        # Prepare results entry
        results[fire_name] = {"missing": [], "present": []} 

        for key, filename in expected_files.items():
            # Full path to expected file
            path = os.path.join(folder, filename)
            # Check if file exists
            if os.path.exists(path):
                results[fire_name]["present"].append(filename)
            else:
                results[fire_name]["missing"].append(filename)

        # Print summary for this fire
        if len(results[fire_name]["missing"]) == 0:
            print("     All expected files present")
        else:
            print("     Missing files:")
            for m in results[fire_name]["missing"]:
                print(f"    - {m}")

    return results

# %% [markdown]
# Validate raster integrity for each file

# %%
def validate_raster(path):
    """Return (is_valid, message, metadata)."""
    try:
        # Open raster file
        with rasterio.open(path) as src:
            # Read first band
            arr = src.read(1)

            # Check for empty or all-NaN rasters
            if arr.size == 0:
                return False, "Empty raster", None
            
            if np.all(np.isnan(arr)):
                return False, "Raster contains only NaN values", None

            # Collect metadata
            meta = {
                "shape": arr.shape, # Pixels (rows, cols)
                "crs": src.crs, # Coordinate Reference System
                "transform": src.transform, # Affine transform mapping pixel to coords
                "dtype": src.dtypes[0], # Data type
                "nodata": src.nodata # NoData value
            }

            return True, "OK", meta

    # Handle raster-specific errors
    except RasterioError as e:
        return False, f"Rasterio error: {str(e)}", None
    except Exception as e:
        return False, f"General error: {str(e)}", None

# %% [markdown]
# Validate raster alignment in fire folder

# %%
def check_alignment(metadata_dict):
    """Check if all rasters share the same resolution, shape, and transform."""
    # Extract metadata
    metas = list(metadata_dict.values())

    # Check unique shapes and transforms
    shapes = {m["shape"] for m in metas}
    transforms = {m["transform"] for m in metas}

    # Determine if all rasters are aligned
    aligned = (len(shapes) == 1) and (len(transforms) == 1)

    return aligned, shapes, transforms

# %% [markdown]
# Run validation on all fires

# %%
def validate_all_rasters(fire_root, expected_files):
    print("\n# Validating raster contents #")

    # Get all fire folders
    fire_folders = [
        os.path.join(fire_root, f)
        for f in os.listdir(fire_root)
        if os.path.isdir(os.path.join(fire_root, f))
    ]

    # Loop over each fire folder
    for folder in fire_folders:
        fire_name = os.path.basename(folder)
        print(f"\n{fire_name}")

        # Store metadata for rasters that pass validation
        metadata_per_raster = {}

        # Validate each expected raster
        for key, filename in expected_files.items():
            path = os.path.join(folder, filename)

            if not os.path.exists(path):
                print(f"Missing: {filename}")
                continue

            # Call validation function
            valid, message, meta = validate_raster(path)

            # Print validation result and store metadata if valid
            if not valid:
                print(f"    {filename} — INVALID: {message}")
            else:
                print(f"    {filename} — OK")
                metadata_per_raster[filename] = meta

        # Alignment check
        if len(metadata_per_raster) > 1:
            # Call alignment check function
            aligned, shapes, transforms = check_alignment(metadata_per_raster)

            # Print alignment results
            if aligned:
                print("\n    Rasters aligned (shape + transform match)")
            else:
                print("\n    Rasters NOT aligned:")
                print(f"    Shapes found: {shapes}")
                print(f"    Transforms found: {transforms}")

# %% [markdown]
# Run functions

# %%
fire_root = "../data/raw"
file_check = check_expected_files(fire_root, expected_files) # Check file existence

validate_all_rasters(fire_root, expected_files) # Validate contents and alignment
# Out:
# # Checking folder structure and file existence #
#
# Checking: BOOTLEG
#      All expected files present
#
# Checking: CAMP
#      All expected files present
#
# Checking: CARR
#      All expected files present
#
# Checking: DIXIE
#      All expected files present
#
# Checking: GLASS
#      All expected files present
#
# Checking: ZOGG
#      All expected files present
#
# # Validating raster contents #
#
# BOOTLEG
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(1797, 2927), (55, 89), (12, 19), (1796, 2927)}
#     Transforms found: {Affine(0.0002694945852358564, 0.0, -121.47373031863273,
#        0.0, -0.0002694945852358564, 42.899359982747626), Affine(0.008983152841195215, 0.0, -121.4791758714829,
#        0.0, -0.008983152841195215, 42.903537969548346), Affine(0.04491576420597607, 0.0, -121.49714217716527,
#        0.0, -0.04491576420597607, 42.939470580913124), Affine(0.00026949458523585647, 0.0, -121.47386092432905,
#        0.0, -0.00026949458523585647, 42.89938080567953), Affine(0.00026949458523585647, 0.0, -121.4738758113066,
#        0.0, -0.00026949458523585647, 42.899226056184574)}
#
# CAMP
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(34, 49), (1111, 1578), (1112, 1579), (1112, 1578), (8, 11)}
#     Transforms found: {Affine(0.008983152841195215, 0.0, -121.78460306808354,
#        0.0, -0.008983152841195215, 39.90316492058915), Affine(0.0002694945852358564, 0.0, -121.777989705364,
#        0.0, -0.0002694945852358564, 39.89799878697589), Affine(0.00026949458523585647, 0.0, -121.7778508164751,
#        0.0, -0.00026949458523585647, 39.8980196099078), Affine(0.04491576420597607, 0.0, -121.81155252660712,
#        0.0, -0.04491576420597607, 39.93011437911273), Affine(0.00026949458523585647, 0.0, -121.77786570345265,
#        0.0, -0.00026949458523585647, 39.897864860412845)}
#
# CARR
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(1652, 1417), (51, 44), (11, 9), (1653, 1417)}
#     Transforms found: {Affine(0.008983152841195215, 0.0, -122.7907161862974,
#        0.0, -0.008983152841195215, 40.945210650167795), Affine(0.00026949458523585647, 0.0, -122.7838889901381,
#        0.0, -0.00026949458523585647, 40.937574970252776), Affine(0.0002694945852358564, 0.0, -122.78374349746423,
#        0.0, -0.0002694945852358564, 40.93743940223059), Affine(0.00026949458523585647, 0.0, -122.78387410316054,
#        0.0, -0.00026949458523585647, 40.937460225162496), Affine(0.04491576420597607, 0.0, -122.79969933913858,
#        0.0, -0.04491576420597607, 40.96317695585018)}
#
# DIXIE
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(6, 6), (875, 851), (875, 852), (28, 27)}
#     Transforms found: {Affine(0.00026949458523585647, 0.0, -115.49971984579813,
#        0.0, -0.00026949458523585647, 45.65346071729503), Affine(0.008983152841195215, 0.0, -115.50537923208807,
#        0.0, -0.008983152841195215, 45.66136589179528), Affine(0.0002694945852358564, 0.0, -115.4998438477095,
#        0.0, -0.0002694945852358564, 45.65359464385807), Affine(0.04491576420597607, 0.0, -115.52334553777047,
#        0.0, -0.04491576420597607, 45.67933219747766), Affine(0.00026949458523585647, 0.0, -115.49970495882059,
#        0.0, -0.00026949458523585647, 45.65361546678998)}
#
# GLASS
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(898, 835), (898, 836), (7, 6), (28, 26)}
#     Transforms found: {Affine(0.04491576420597607, 0.0, -122.66495204652065,
#        0.0, -0.04491576420597607, 38.717388745551375), Affine(0.00026949458523585647, 0.0, -122.66019097551484,
#        0.0, -0.00026949458523585647, 38.67274247593064), Affine(0.00026949458523585647, 0.0, -122.6601760885373,
#        0.0, -0.00026949458523585647, 38.672897225425594), Affine(0.0002694945852358564, 0.0, -122.6603149774262,
#        0.0, -0.0002694945852358564, 38.672876402493685), Affine(0.008983152841195215, 0.0, -122.66495204652067,
#        0.0, -0.008983152841195215, 38.6814561341866)}
#
# ZOGG
#     pre_ndvi.tif — OK
#     post_ndvi.tif — OK
#     pre_nbr.tif — OK
#     post_nbr.tif — OK
#     chirps_precip.tif — OK
#     era5_temp.tif — OK
#     landcover.tif — OK
#     srtm_dem.tif — OK
#
#     Rasters NOT aligned:
#     Shapes found: {(957, 657), (30, 20), (6, 4)}
#     Transforms found: {Affine(0.008983152841195215, 0.0, -122.70986781072664,
#        0.0, -0.008983152841195215, 40.558935077996395), Affine(0.0002694945852358564, 0.0, -122.70801551901295,
#        0.0, -0.0002694945852358564, 40.55098416700237), Affine(0.00026949458523585647, 0.0, -122.70816101168683,
#        0.0, -0.00026949458523585647, 40.55111973502456), Affine(0.04491576420597607, 0.0, -122.70986781072664,
#        0.0, -0.04491576420597607, 40.558935077996395), Affine(0.00026949458523585647, 0.0, -122.70814612470927,
#        0.0, -0.00026949458523585647, 40.55100498993428)}
