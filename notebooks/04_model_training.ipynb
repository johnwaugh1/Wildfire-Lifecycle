# %% [markdown]
# Imports

# %%
import os
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# Load Stacked Dataset

# %%
data_path = "../data/processed/stacked_dataset.parquet"
df = pd.read_parquet(data_path)

print("Loaded dataset:", df.shape)
# Out:
# Loaded dataset: (35954029, 20)

# %% [markdown]
# Confusion Matrix Plot Function

# %%
def plot_confusion(cm, classes, title, save_path):
    plt.figure(figsize=(6,5))
    plt.imshow(cm, interpolation="nearest")
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], "d"),
                     ha="center", va="center")

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()

    plt.savefig(save_path)
    plt.close()

# %% [markdown]
# Stratified Subsampling per split

# %%
def stratified_subsample(df_split, target_samples):
    """Stratified subsampling inside a single fire-group split."""
    target_samples = min(target_samples, len(df_split))
    
    sss = StratifiedShuffleSplit(
        n_splits=1,
        train_size=target_samples,
        random_state=42
    )
    idx, _ = next(sss.split(df_split, df_split["severity"]))
    return df_split.iloc[idx].reset_index(drop=True)

# %% [markdown]
# Balancing Function

# %%
def balance_classes(df, max_per_class):
    groups = []
    for cls, subset in df.groupby("severity"):
        take = min(len(subset), max_per_class)
        groups.append(subset.sample(take, random_state=42))
    return pd.concat(groups).sample(frac=1, random_state=42)

# %% [markdown]
# Train/Val/Test Split

# %%
# Fire-wise Split
fires = df["fire_name"].unique()
fires_train, fires_temp = train_test_split(
    fires, test_size=0.3, random_state=42
)
fires_val, fires_test = train_test_split(
    fires_temp, test_size=0.5, random_state=42
)

print("Train fires:", fires_train)
print("Val fires:", fires_val)
print("Test fires:", fires_test)

df_train_full = df[df["fire_name"].isin(fires_train)]
df_val_full   = df[df["fire_name"].isin(fires_val)]
df_test_full  = df[df["fire_name"].isin(fires_test)]

df_train = balance_classes(df_train_full, max_per_class=50_000)
df_val   = balance_classes(df_val_full,   max_per_class=10_000)
df_test  = balance_classes(df_test_full,  max_per_class=10_000)

print("Train:", len(df_train))
print("Val:", len(df_val))
print("Test:", len(df_test))

# Final Splits
X_train = df_train.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_train = df_train["severity"]

X_val = df_val.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_val = df_val["severity"]

X_test = df_test.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_test = df_test["severity"]
# Out:
# Train fires: ['bootleg_fire' 'zogg_fire' 'camp_fire' 'dixie_fire' 'carr_fire'
#  'glass_fire']
# Val fires: ['east_troublesome_fire']
# Test fires: ['red_salmon_fire' 'caldor_fire']
# Train: 200000
# Val: 30257
# Test: 40000
# Train: 200000
# Val: 30257
# Test: 40000

# %% [markdown]
# Model Definitions

# %%
models = {
    "logistic_regression": LogisticRegression(
        max_iter=2000,
        class_weight="balanced"
    ),
    "random_forest": RandomForestClassifier(
        n_estimators=600,
        max_depth=25,            
        min_samples_leaf=5,     
        class_weight="balanced_subsample",
        n_jobs=-1
    ),
    "xgboost": XGBClassifier(
        n_estimators=700,
        max_depth=8,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        tree_method="hist",
        eval_metric="mlogloss"
    ),
    "LightGBM": LGBMClassifier(
        n_estimators=800,
        learning_rate=0.05,
        num_leaves=40,
        max_depth=15,
        min_data_in_leaf=50,
        class_weight="balanced",
        verbose=-1
    ),
    "catboost": CatBoostClassifier(
        iterations=800,
        depth=8,
        learning_rate=0.05,
        loss_function="MultiClass",
        class_weights=[1, 10, 12, 40],
        verbose=False
    ),
}

os.makedirs("../data/models", exist_ok=True)
os.makedirs("../figures", exist_ok=True)

# %% [markdown]
# Train and Evaluate Models

# %%
results = []

for name, model in models.items():
    print(f"Training {name}")

    # Train
    model.fit(X_train, y_train)

    # Validation prediction
    val_pred = model.predict(X_val)
    test_pred = model.predict(X_test)

    # Validation metrics
    val_f1 = f1_score(y_val, val_pred, average="weighted")
    val_precision = precision_score(y_val, val_pred, average="weighted", zero_division=0)
    val_recall = recall_score(y_val, val_pred, average="weighted", zero_division=0)
    val_accuracy = accuracy_score(y_val, val_pred)

    # Test metrics
    test_f1 = f1_score(y_test, test_pred, average="weighted")
    test_precision = precision_score(y_test, test_pred, average="weighted", zero_division=0)
    test_recall = recall_score(y_test, test_pred, average="weighted", zero_division=0)
    test_accuracy = accuracy_score(y_test, test_pred)

    print(f"{name} validation F1:", val_f1)
    print(f"{name} test F1:", test_f1)

    # Save model
    model_path = f"../data/models/{name}.pkl"
    joblib.dump(model, model_path)
    print(f"Saved model: {model_path}")

    # Confusion matrix
    cm_val = confusion_matrix(y_val, val_pred)
    cm_test = confusion_matrix(y_test, test_pred)

    plot_confusion(
        cm_val,
        classes=np.unique(y_train),
        title=f"{name} - Validation Confusion Matrix",
        save_path=f"../figures/{name}_val_cm.png"
    )

    plot_confusion(
        cm_test,
        classes=np.unique(y_train),
        title=f"{name} - Test Confusion Matrix",
        save_path=f"../figures/{name}_test_cm.png"
    )

    results.append({
        "model": name,
        "val_f1": val_f1,
        "val_precision": val_precision,
        "val_recall": val_recall,
        "val_accuracy": val_accuracy,
        "test_f1": test_f1,
        "test_precision": test_precision,
        "test_recall": test_recall,
        "test_accuracy": test_accuracy
    })

    # Print classification report
    print("\nClassification Report (Validation):")
    print(classification_report(y_val, val_pred))

    print("\nClassification Report (Test):")
    print(classification_report(y_test, test_pred))
# Out:
# Training logistic_regression
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 2000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=2000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# logistic_regression validation F1: 0.2092460822099842
# logistic_regression test F1: 0.24711302246402833
# Saved model: ../data/models/logistic_regression.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.23      0.05      0.09     10000
#            1       0.47      0.02      0.04     10000
#            2       0.34      0.94      0.50     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.34     30257
#    macro avg       0.26      0.25      0.16     30257
# weighted avg       0.34      0.34      0.21     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.80      0.14      0.23     10000
#            1       0.34      0.12      0.17     10000
#            2       0.27      0.44      0.33     10000
#            3       0.19      0.35      0.25     10000
#
#     accuracy                           0.26     40000
#    macro avg       0.40      0.26      0.25     40000
# weighted avg       0.40      0.26      0.25     40000
#
# Training random_forest
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.23      0.05      0.09     10000
#            1       0.47      0.02      0.04     10000
#            2       0.34      0.94      0.50     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.34     30257
#    macro avg       0.26      0.25      0.16     30257
# weighted avg       0.34      0.34      0.21     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.80      0.14      0.23     10000
#            1       0.34      0.12      0.17     10000
#            2       0.27      0.44      0.33     10000
#            3       0.19      0.35      0.25     10000
#
#     accuracy                           0.26     40000
#    macro avg       0.40      0.26      0.25     40000
# weighted avg       0.40      0.26      0.25     40000
#
# Training random_forest
# random_forest validation F1: 0.1641960566299031
# random_forest test F1: 0.3980413928230656
# random_forest validation F1: 0.1641960566299031
# random_forest test F1: 0.3980413928230656
# Saved model: ../data/models/random_forest.pkl
# Saved model: ../data/models/random_forest.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.00      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.08      0.25      0.12     30257
# weighted avg       0.11      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.46      0.28      0.35     10000
#            1       0.29      0.20      0.24     10000
#            2       0.34      0.48      0.40     10000
#            3       0.55      0.70      0.61     10000
#
#     accuracy                           0.41     40000
#    macro avg       0.41      0.41      0.40     40000
# weighted avg       0.41      0.41      0.40     40000
#
# Training xgboost
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.00      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.08      0.25      0.12     30257
# weighted avg       0.11      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.46      0.28      0.35     10000
#            1       0.29      0.20      0.24     10000
#            2       0.34      0.48      0.40     10000
#            3       0.55      0.70      0.61     10000
#
#     accuracy                           0.41     40000
#    macro avg       0.41      0.41      0.40     40000
# weighted avg       0.41      0.41      0.40     40000
#
# Training xgboost
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# xgboost validation F1: 0.16435710493101877
# xgboost test F1: 0.38936827379535077
# Saved model: ../data/models/xgboost.pkl
# Saved model: ../data/models/xgboost.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.50      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.21      0.25      0.12     30257
# weighted avg       0.27      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.35      0.27      0.30     10000
#            1       0.33      0.27      0.30     10000
#            2       0.32      0.34      0.33     10000
#            3       0.55      0.74      0.63     10000
#
#     accuracy                           0.40     40000
#    macro avg       0.39      0.40      0.39     40000
# weighted avg       0.39      0.40      0.39     40000
#
# Training LightGBM
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.50      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.21      0.25      0.12     30257
# weighted avg       0.27      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.35      0.27      0.30     10000
#            1       0.33      0.27      0.30     10000
#            2       0.32      0.34      0.33     10000
#            3       0.55      0.74      0.63     10000
#
#     accuracy                           0.40     40000
#    macro avg       0.39      0.40      0.39     40000
# weighted avg       0.39      0.40      0.39     40000
#
# Training LightGBM
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# LightGBM validation F1: 0.16444780343130866
# LightGBM test F1: 0.4024242650736597
# Saved model: ../data/models/LightGBM.pkl
# Saved model: ../data/models/LightGBM.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.42      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.19      0.25      0.12     30257
# weighted avg       0.25      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.45      0.27      0.34     10000
#            1       0.29      0.22      0.25     10000
#            2       0.37      0.47      0.41     10000
#            3       0.53      0.72      0.61     10000
#
#     accuracy                           0.42     40000
#    macro avg       0.41      0.42      0.40     40000
# weighted avg       0.41      0.42      0.40     40000
#
# Training catboost
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50     10000
#            1       0.42      0.00      0.00     10000
#            2       0.00      0.00      0.00     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.33     30257
#    macro avg       0.19      0.25      0.12     30257
# weighted avg       0.25      0.33      0.16     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.45      0.27      0.34     10000
#            1       0.29      0.22      0.25     10000
#            2       0.37      0.47      0.41     10000
#            3       0.53      0.72      0.61     10000
#
#     accuracy                           0.42     40000
#    macro avg       0.41      0.42      0.40     40000
# weighted avg       0.41      0.42      0.40     40000
#
# Training catboost
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\johnm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# catboost validation F1: 0.21579521983830796
# catboost test F1: 0.37314559557760596
# Saved model: ../data/models/catboost.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.32      0.78      0.45     10000
#            1       0.23      0.08      0.12     10000
#            2       0.24      0.05      0.08     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.30     30257
#    macro avg       0.20      0.23      0.16     30257
# weighted avg       0.26      0.30      0.22     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.07      0.13     10000
#            1       0.27      0.18      0.22     10000
#            2       0.48      0.64      0.55     10000
#            3       0.45      0.87      0.59     10000
#
#     accuracy                           0.44     40000
#    macro avg       0.54      0.44      0.37     40000
# weighted avg       0.54      0.44      0.37     40000
#
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.32      0.78      0.45     10000
#            1       0.23      0.08      0.12     10000
#            2       0.24      0.05      0.08     10000
#            3       0.00      0.00      0.00       257
#
#     accuracy                           0.30     30257
#    macro avg       0.20      0.23      0.16     30257
# weighted avg       0.26      0.30      0.22     30257
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.07      0.13     10000
#            1       0.27      0.18      0.22     10000
#            2       0.48      0.64      0.55     10000
#            3       0.45      0.87      0.59     10000
#
#     accuracy                           0.44     40000
#    macro avg       0.54      0.44      0.37     40000
# weighted avg       0.54      0.44      0.37     40000

# %% [markdown]
# Save comparison table

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("../data/models/metrics.csv", index=False)
print("\nSaved metrics table to ../data/models/metrics.csv")
print(results_df)
# Out:
# Saved metrics table to ../data/models/metrics.csv
#                  model    val_f1  val_precision  val_recall  val_accuracy  \
# 0  logistic_regression  0.209246       0.343783    0.335889      0.335889
# 1        random_forest  0.164196       0.109232    0.330502      0.330502
# 2              xgboost  0.164357       0.274464    0.330469      0.330469
# 3             LightGBM  0.164448       0.246900    0.330403      0.330403
# 4             catboost  0.215795       0.260124    0.301418      0.301418
#
#     test_f1  test_precision  test_recall  test_accuracy
# 0  0.247113        0.400055     0.261325       0.261325
# 1  0.398041        0.407778     0.414350       0.414350
# 2  0.389368        0.385955     0.403725       0.403725
# 3  0.402424        0.409972     0.420300       0.420300
# 4  0.373146        0.540778     0.441100       0.441100
