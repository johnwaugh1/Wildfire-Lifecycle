# %% [markdown]
# Imports

# %%
import os
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt # For confusion matrices

# Sci-kit learn utilities for splitting, training, evaluating
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# Machine learning models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# Load Stacked Dataset

# %%
data_path = "../data/processed/stacked_dataset.parquet"
df = pd.read_parquet(data_path)

print("Loaded dataset:", df.shape) # Dataset dimensions
# Out:
# Loaded dataset: (11478601, 20)

# %% [markdown]
# Confusion Matrix Plot Function

# %%
def plot_confusion(cm, classes, title, save_path):
    plt.figure(figsize=(6,5)) # Create figure
    plt.imshow(cm, interpolation="nearest") # Render confusion matrix
    plt.title(title) # Set title
    plt.colorbar() # Add color bar
    tick_marks = np.arange(len(classes)) # Class tick marks 
    plt.xticks(tick_marks, classes, rotation=45)  # X-axis labels
    plt.yticks(tick_marks, classes) # Y-axis labels

    # Loop through matrix cells and draw value text in each
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], "d"),
                     ha="center", va="center")

    plt.ylabel("True label") # Y-axis label
    plt.xlabel("Predicted label") # X-axis label   
    plt.tight_layout() # Adjust layout to prevent overlap

    plt.savefig(save_path)
    plt.close()

# %% [markdown]
# Train/Val/Test Split

# %%
"""
Removed balancing function because I was getting similar results with or without
it using the entire dataset. Also split by fire name directly instead of using 
percentages like before.
"""

fires_train = ["BOOTLEG", "CAMP", "CARR", "GLASS"]
fires_val = ["DIXIE"]
fires_test = ["ZOGG"]

print("Train fires:", fires_train)
print("Val fires:", fires_val)
print("Test fires:", fires_test)

# Create split dataframes to assign pixels from each fire to correct set
df_train = df[df["fire_name"].isin(fires_train)]
df_val   = df[df["fire_name"].isin(fires_val)]
df_test  = df[df["fire_name"].isin(fires_test)]

print("Train:", len(df_train))
print("Val:", len(df_val))
print("Test:", len(df_test))

# Drop target label and non-feature columns to avoid data leakage
X_train = df_train.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_train = df_train["severity"]

X_val = df_val.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_val = df_val["severity"]

X_test = df_test.drop(columns=["severity", "fire_name", "dnbr", "dndvi", "nbr_post", "ndvi_post"])
y_test = df_test["severity"]
# Out:
# Train fires: ['BOOTLEG', 'CAMP', 'CARR', 'GLASS']
# Val fires: ['DIXIE']
# Test fires: ['ZOGG']
# Train: 10104352
# Val: 745500
# Test: 628749

# %% [markdown]
# Model Definitions

# %%
models = {
    "logistic_regression": LogisticRegression(
        max_iter=3000,
        class_weight="balanced",
        solver="saga",
        penalty="l2",
        C=0.5
    ),
    "random_forest": RandomForestClassifier(
        n_estimators=400, # Number of trees
        max_depth=12, # Limit tree depth to avoid overly complex trees           
        min_samples_leaf=50, # Force minimum samples per leaf
        min_samples_split=200, # Minimum samples to split a node 
        class_weight="balanced_subsample", # Balance classes in each bootstrap sample
        bootstrap=True, # Use bootstrap samples for tree training
        n_jobs=-1 # Use all CPU cores
    ),
    "xgboost": XGBClassifier(
        n_estimators=300, # Number of boosting rounds, more rounds means stronger learning but slower training
        max_depth=5, # Maximum tree depth, controls model complexity 
        learning_rate=0.05, # Shrinks contribution of each tree, more stable learning
        subsample=0.6, # Fraction of samples used per tree to prevent overfitting
        colsample_bytree=0.6, # Fraction of features used per tree to prevent overfitting
        min_child_weight=50, # Minimum sum of instance weight needed in a child
        reg_lambda=2.0, # L2 regularization term on weights
        reg_alpha=1.0, # L1 regularization term on weights
        tree_method="hist", # Use histogram-based algorithm for faster training
        eval_metric="mlogloss", # Optimization metric for multi-class classification
    ),
    "LightGBM": LGBMClassifier(
        n_estimators=500, # Number of boosting iterations
        learning_rate=0.05, # Shrinkage rate
        num_leaves=30, # Controls tree complexity
        max_depth=8, # Depth limit to prevent overly complex trees
        min_data_in_leaf=200, # Minimum samples per leaf to avoid overfitting
        feature_fraction=0.7, # Fraction of features used per tree to prevent overfitting
        bagging_fraction=0.7, # Fraction of samples used per tree to prevent overfitting
        bagging_freq=3, # Frequency for bagging
        class_weight="balanced", # Auto-weight classes based on frequency
        verbose=-1 # Silence training output
    ),
    "catboost": CatBoostClassifier(
        iterations=500, # Number of boosting rounds
        depth=6, # Tree depth
        learning_rate=0.05, # Shrinkage rate
        loss_function="MultiClass", # Multi-class classification loss
        auto_class_weights="Balanced",
        random_strength=1.5, # Randomness to prevent overfitting
        verbose=False # Silence training output
    ),
}

os.makedirs("../data/models", exist_ok=True)
os.makedirs("../figures", exist_ok=True)

# %% [markdown]
# Train and Evaluate Models

# %%
results = [] # Stores valuation metrics for all models

for name, model in models.items():
    print(f"Training {name}")

    # Train
    model.fit(X_train, y_train)

    # Validation prediction
    val_pred = model.predict(X_val)
    # Test prediction
    test_pred = model.predict(X_test)

    # Validation metrics
    val_f1 = f1_score(y_val, val_pred, average="weighted")
    val_precision = precision_score(y_val, val_pred, average="weighted", zero_division=0)
    val_recall = recall_score(y_val, val_pred, average="weighted", zero_division=0)
    val_accuracy = accuracy_score(y_val, val_pred)

    # Test metrics
    test_f1 = f1_score(y_test, test_pred, average="weighted")
    test_precision = precision_score(y_test, test_pred, average="weighted", zero_division=0)
    test_recall = recall_score(y_test, test_pred, average="weighted", zero_division=0)
    test_accuracy = accuracy_score(y_test, test_pred)

    print(f"{name} validation F1:", val_f1)
    print(f"{name} test F1:", test_f1)

    # Save model
    model_path = f"../data/models/{name}.pkl"
    joblib.dump(model, model_path)
    print(f"Saved model: {model_path}")

    # Confusion matrix
    cm_val = confusion_matrix(y_val, val_pred)
    cm_test = confusion_matrix(y_test, test_pred)

    plot_confusion(
        cm_val,
        classes=np.unique(y_train),
        title=f"{name} - Validation Confusion Matrix",
        save_path=f"../figures/{name}_val_cm.png"
    )

    plot_confusion(
        cm_test,
        classes=np.unique(y_train),
        title=f"{name} - Test Confusion Matrix",
        save_path=f"../figures/{name}_test_cm.png"
    )

    results.append({
        "model": name,
        "val_f1": val_f1,
        "val_precision": val_precision,
        "val_recall": val_recall,
        "val_accuracy": val_accuracy,
        "test_f1": test_f1,
        "test_precision": test_precision,
        "test_recall": test_recall,
        "test_accuracy": test_accuracy
    })

    # Print classification report
    print("\nClassification Report (Validation):")
    print(classification_report(y_val, val_pred))

    print("\nClassification Report (Test):")
    print(classification_report(y_test, test_pred))
# Out:
# Training logistic_regression
# logistic_regression validation F1: 0.23482838567884237
# logistic_regression test F1: 0.3314327237055485
# Saved model: ../data/models/logistic_regression.pkl
#
# Classification Report (Validation):
#               precision    recall  f1-score   support
#
#            0       0.75      0.08      0.14    388277
#            1       0.31      0.41      0.35    257908
#            2       0.21      0.52      0.30     99284
#            3       0.00      0.00      0.00        31
#
#     accuracy                           0.25    745500
#    macro avg       0.32      0.25      0.20    745500
# weighted avg       0.53      0.25      0.23    745500
#
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.47      0.78      0.59    300482
#            1       0.18      0.06      0.09     70394
#            2       0.27      0.06      0.10    220499
# ...

# %% [markdown]
# Save comparison table

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("../data/models/metrics.csv", index=False)
print("\nSaved metrics table to ../data/models/metrics.csv")
print(results_df)
# Out:
# Saved metrics table to ../data/models/metrics.csv
#                  model    val_f1  val_precision  val_recall  val_accuracy  \
# 0  logistic_regression  0.234828       0.528148    0.250066      0.250066
# 1        random_forest  0.394884       0.452284    0.508785      0.508785
# 2              xgboost  0.359191       0.377681    0.510939      0.510939
# 3             LightGBM  0.463250       0.455699    0.532653      0.532653
# 4             catboost  0.517643       0.541657    0.506657      0.506657
#
#     test_f1  test_precision  test_recall  test_accuracy
# 0  0.331433        0.343903     0.409973       0.409973
# 1  0.348561        0.349610     0.459328       0.459328
# 2  0.329595        0.332395     0.471514       0.471514
# 3  0.337713        0.328044     0.444780       0.444780
# 4  0.337412        0.331330     0.441750       0.441750
